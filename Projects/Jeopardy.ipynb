# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

jeopardy = pd.read_csv('/Users/elorm/Documents/Repos/Datasets/jeopardy.csv')
jeopardy.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                                                                                       Question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3                         In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4     Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
#
#        Answer
# 0  Copernicus
# 1  Jim Thorpe
# 2     Arizona
# 3  McDonald's
# 4  John Adams

# %%
jeopardy.columns = jeopardy.columns.str.strip(' ')

# %%
# Filtering a dataset by a list of words
def filter_data(data, words):
  # Lowercases all words in the list of words as well as the questions. Returns true is all of the words in the list appear in the question.
  filter = lambda x: all(word.lower() in x.lower() for word in words)
  # Applies the labmda function to the Question column and returns the rows where the function returned True
  return data.loc[data["Question"].apply(filter)]

# %%
# Testing the filter function
filtered = filter_data(jeopardy, ["King", "England"])
print(filtered["Question"])
# Out:
# 4953    Both England's King George V & FDR put their stamp of approval on this "King of Hobbies"
# Name: Question, dtype: object

# %%
# Adding a new column. If the value of the float column is not "None", then we cut off the first character (which is a dollar sign), and replace all commas with nothing, and then cast that value to a float. If the answer was "None", then we just enter a 0.
jeopardy["Float Value"] = jeopardy["Value"].apply(lambda x: float(x[1:].replace(',','')) if x != "None" else 0)

# %%
jeopardy.sample(10)
# Out:
#       Show Number    Air Date             Round                  Category  \
# 5373         5914  2010-05-06  Double Jeopardy!        AMERICANS IN PARIS
# 5423         2047  1993-06-29  Double Jeopardy!                 NOVELISTS
# 2996         5079  2006-10-12         Jeopardy!              "B" PREPARED
# 2644         6125  2011-04-08         Jeopardy!       YES, THAT'S "WHITE"
# 4608         5512  2008-07-22  Double Jeopardy!     WORD & PHRASE ORIGINS
# 2327         4595  2004-07-23         Jeopardy!             MYTHELLANEOUS
# 3775         6144  2011-05-05         Jeopardy!  POLITICIANS MAKE ME CUSS
# 5127         4842  2005-10-04  Double Jeopardy!               CHAD IS RAD
# 4563         5512  2008-07-22         Jeopardy!        HOP ON POP CULTURE
# 5112         4842  2005-10-04         Jeopardy!                 COMPANIES
#
#        Value  \
# 5373  $3,000
# 5423    $200
# 2996    $600
# 2644    $800
# 4608   $1600
# 2327    $200
# 3775    $400
# 5127    $800
# 4563    $400
# 5112    $800
#
#                                                                                                                 Question  \
# 5373                       In March 1971 this rocker closed the door on his band & moved to Paris to focus on his poetry
# 5423                        This novelist's youthful voyages provided the basis for such works as "Lord Jim" & "Typhoon"
# 2996                                                                     This period lasted from about 3500 to 1500 B.C.
# 2644                                              A chess piece, or a company involved in a friendly takeover of another
# 4608  Politically, this word for a region reflecting a large trend comes from a lead sheep with a ringer around its neck
# 2327       The mythical Sumerian hero Utnapishtim built a big vessel at God's urging & thereby survived this catastrophe
# 3775                                                                             "For the love of" Wyoming senator Enzi!
# 5127                                                       In the 11th century the kings of Chad converted to this faith
# 4563                        Sydney's dad, Jack, was a CIA double agent working against SD-6 on this Jennifer Garner show
# 5112                                   Orange & Rockland Utilities is a subsidiary of this company named for an inventor
#
#                            Answer  Float Value
# 5373                 Jim Morrison       3000.0
# 5423                       Conrad        200.0
# 2996               the Bronze Age        600.0
# 2644               a white knight        800.0
# 4608                 a bellwether       1600.0
# 2327                      a flood        200.0
# 3775                         Mike        400.0
# 5127                        Islam        800.0
# 4563                        Alias        400.0
# 5112  Consolidated Edison (ConEd)        800.0

# %%
filtered = filter_data(jeopardy, ["King"])
print(filtered["Float Value"].mean())
# Out:
# 670.8108108108108

# %%
# A function to find the unique answers of a set of data
def get_answer_counts(data):
    return data["Answer"].value_counts()

# Testing the answer count function
print(get_answer_counts(filtered))
# Out:
# Henry VIII               3
# Richard III              2
# Louisiana                2
# The Cars                 1
# "The King And I"         1
#                         ..
# Skull Island             1
# Alfred Lord Tennyson     1
# screw in a light bulb    1
# Avalon                   1
# Spartacus                1
# Name: Answer, Length: 181, dtype: int64
